# %%
import pandas as pd

# %%
# Load the CSV file (update the path if needed)
file_path = 'Resources/puntos-de-abastecimiento-de-agua-a-nivel-municipal-monterrey.csv'
df = pd.read_csv(file_path)

# %%
print(df.columns)
# Out:
# Index(['Ejercicio', 'Mes', 'Nombre del punto de distribución',
#        'Tipo de asentamiento ', 'Denominación del asentamiento',
#        'Nombre de la vialidad', 'Número de vialidad (en su caso)',
#        'Tipo de abastecimiento', 'Días ', 'Horarios', 'Contacto',
#        'Capacidad de la unidad ', 'Geopoint', 'Nota'],
#       dtype='object')

# %%
# Step 1: Assign IDs starting from 1 based on the existing number of rows
df['ID'] = range(1, len(df) + 1)

# Move the 'ID' column to the leftmost position
df = df[['ID'] + [col for col in df.columns if col != 'ID']]

# Display the updated DataFrame
df.head(5)
# Out:
#    ID Ejercicio      Mes                   Nombre del punto de distribución  \
# 0   1      2023  Octubre  Centro de Bienestar Familiar Burócratas munici...
# 1   2      2023  Octubre    Centro de Bienestar Familiar  Valle del Mirador
# 2   3      2023  Octubre     Centro de Bienestar Familiar Tierra y Libertad
# 3   4      2023  Octubre         Centro de Bienestar Familiar Nueva Morelos
# 4   5      2023  Octubre  Centro de Bienestar Familiar Antonio I. Villar...
#
#   Tipo de asentamiento  Denominación del asentamiento  \
# 0               Colonia        Burócratas Municipales
# 1               Colonia             Valle del Mirador
# 2               Colonia             Tierra y Libertad
# 3               Colonia                 Nueva Morelos
# 4               Colonia         Antonio I. Villarreal
#
#               Nombre de la vialidad Número de vialidad (en su caso)  \
# 0             Avenida Alfonso Reyes                      Sin número
# 1                Calle Paseo Alicia                      Sin número
# 2                Calle Liga Femenil                      Sin número
# 3                  Calle Marea Alta                      Sin número
# 4  Calle Veteranos de la Revolución                      Sin número
#
#   Tipo de abastecimiento                                       Días   \
# 0             Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 1             Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 2             Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 3             Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 4             Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
#
#                 Horarios        Contacto Capacidad de la unidad   \
# 0  8:00 a.m. a 5:00 p.m.  81-51-02-73-23             1000 litros
# 1  8:00 a.m. a 5:00 p.m.  81-51-02-73-19             1000 litros
# 2  8:00 a.m. a 5:00 p.m.  81-51-02-71-59             1000 litros
# 3  8:00 a.m. a 5:00 p.m.  81-51-02-73-53             1000 litros
# 4  8:00 a.m. a 5:00 p.m.  81-51-02-71-31             1000 litros
#
#                                   Geopoint            Nota
# 0                 25.6352203, -100.2990693    1 Contenedor
# 1  25.639017498380895, -100.30948000096342    1 Contenedor
# 2   25.741158636659847, -100.3381042670378  2 Contenedores
# 3  25.718641664223934, -100.34674910367468    1 Contenedor
# 4    25.70494909056859, -100.3556544251508    1 Contenedor

# %%
# Step 2: Combine 'Ejercicio' (Year) and 'Mes' (Month) into a single column
df['Fecha'] = df['Ejercicio'].astype(str) + '-' + df['Mes']

# Move the column to the leftmost position
df = df[['ID','Fecha'] + [col for col in df.columns if col != 'ID''Fecha']]

#Droping columns whith similar data
df.drop(columns=['Ejercicio', 'Mes', 'Contacto', 'Nota'], inplace=True)

# Display the updated DataFrame
df.head(5)
# Out:
#    ID         Fecha  ID                   Nombre del punto de distribución  \
# 0   1  2023-Octubre   1  Centro de Bienestar Familiar Burócratas munici...
# 1   2  2023-Octubre   2    Centro de Bienestar Familiar  Valle del Mirador
# 2   3  2023-Octubre   3     Centro de Bienestar Familiar Tierra y Libertad
# 3   4  2023-Octubre   4         Centro de Bienestar Familiar Nueva Morelos
# 4   5  2023-Octubre   5  Centro de Bienestar Familiar Antonio I. Villar...
#
#   Tipo de asentamiento  Denominación del asentamiento  \
# 0               Colonia        Burócratas Municipales
# 1               Colonia             Valle del Mirador
# 2               Colonia             Tierra y Libertad
# 3               Colonia                 Nueva Morelos
# 4               Colonia         Antonio I. Villarreal
#
#               Nombre de la vialidad Número de vialidad (en su caso)  \
# 0             Avenida Alfonso Reyes                      Sin número
# 1                Calle Paseo Alicia                      Sin número
# 2                Calle Liga Femenil                      Sin número
# 3                  Calle Marea Alta                      Sin número
# 4  Calle Veteranos de la Revolución                      Sin número
#
#   Tipo de abastecimiento                                       Días   \
# 0             Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 1             Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 2             Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 3             Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 4             Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
#
#                 Horarios Capacidad de la unidad   \
# 0  8:00 a.m. a 5:00 p.m.             1000 litros
# 1  8:00 a.m. a 5:00 p.m.             1000 litros
# 2  8:00 a.m. a 5:00 p.m.             1000 litros
# 3  8:00 a.m. a 5:00 p.m.             1000 litros
# 4  8:00 a.m. a 5:00 p.m.             1000 litros
#
#                                   Geopoint         Fecha
# 0                 25.6352203, -100.2990693  2023-Octubre
# 1  25.639017498380895, -100.30948000096342  2023-Octubre
# 2   25.741158636659847, -100.3381042670378  2023-Octubre
# 3  25.718641664223934, -100.34674910367468  2023-Octubre
# 4    25.70494909056859, -100.3556544251508  2023-Octubre

# %%
# Step 3: Split the 'geopoint' column into 'Latitude' and 'Longitude'
df[['Latitude', 'Longitude']] = df['Geopoint'].str.split(', ', expand=True)

# Convert the new columns to float
df['Latitude'] = df['Latitude'].astype(float)
df['Longitude'] = df['Longitude'].astype(float)

# Move the column to the leftmost position
df = df[['ID','Fecha','Latitude','Longitude'] + [col for col in df.columns if col != 'ID''Fecha''Latitude''Longitude']]

# Display the updated DataFrame
df.head(5)
# Out:
#    ID  ID         Fecha         Fecha   Latitude   Longitude  ID  ID  \
# 0   1   1  2023-Octubre  2023-Octubre  25.635220 -100.299069   1   1
# 1   2   2  2023-Octubre  2023-Octubre  25.639017 -100.309480   2   2
# 2   3   3  2023-Octubre  2023-Octubre  25.741159 -100.338104   3   3
# 3   4   4  2023-Octubre  2023-Octubre  25.718642 -100.346749   4   4
# 4   5   5  2023-Octubre  2023-Octubre  25.704949 -100.355654   5   5
#
#           Fecha         Fecha  ...  Número de vialidad (en su caso)  \
# 0  2023-Octubre  2023-Octubre  ...                       Sin número
# 1  2023-Octubre  2023-Octubre  ...                       Sin número
# 2  2023-Octubre  2023-Octubre  ...                       Sin número
# 3  2023-Octubre  2023-Octubre  ...                       Sin número
# 4  2023-Octubre  2023-Octubre  ...                       Sin número
#
#    Tipo de abastecimiento                                       Días   \
# 0              Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 1              Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 2              Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 3              Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
# 4              Contenedor  Lunes, Martes, Miércoles, Jueves y Viernes
#
#                 Horarios Capacidad de la unidad   \
# 0  8:00 a.m. a 5:00 p.m.             1000 litros
# 1  8:00 a.m. a 5:00 p.m.             1000 litros
# 2  8:00 a.m. a 5:00 p.m.             1000 litros
# 3  8:00 a.m. a 5:00 p.m.             1000 litros
# 4  8:00 a.m. a 5:00 p.m.             1000 litros
#
#                                   Geopoint         Fecha         Fecha  \
# 0                 25.6352203, -100.2990693  2023-Octubre  2023-Octubre
# 1  25.639017498380895, -100.30948000096342  2023-Octubre  2023-Octubre
# 2   25.741158636659847, -100.3381042670378  2023-Octubre  2023-Octubre
# 3  25.718641664223934, -100.34674910367468  2023-Octubre  2023-Octubre
# 4    25.70494909056859, -100.3556544251508  2023-Octubre  2023-Octubre
#
#     Latitude   Longitude
# 0  25.635220 -100.299069
# 1  25.639017 -100.309480
# 2  25.741159 -100.338104
# 3  25.718642 -100.346749
# 4  25.704949 -100.355654
#
# [5 rows x 26 columns]

# %%
#Droping columns whith similar data
df.drop(columns=['Geopoint'], inplace=True)

# Drop duplicate columns
df = df.loc[:, ~df.columns.duplicated()]
df.head(5)
# Out:
#    ID         Fecha   Latitude   Longitude  \
# 0   1  2023-Octubre  25.635220 -100.299069
# 1   2  2023-Octubre  25.639017 -100.309480
# 2   3  2023-Octubre  25.741159 -100.338104
# 3   4  2023-Octubre  25.718642 -100.346749
# 4   5  2023-Octubre  25.704949 -100.355654
#
#                     Nombre del punto de distribución Tipo de asentamiento   \
# 0  Centro de Bienestar Familiar Burócratas munici...               Colonia
# 1    Centro de Bienestar Familiar  Valle del Mirador               Colonia
# 2     Centro de Bienestar Familiar Tierra y Libertad               Colonia
# 3         Centro de Bienestar Familiar Nueva Morelos               Colonia
# 4  Centro de Bienestar Familiar Antonio I. Villar...               Colonia
#
#   Denominación del asentamiento             Nombre de la vialidad  \
# 0        Burócratas Municipales             Avenida Alfonso Reyes
# 1             Valle del Mirador                Calle Paseo Alicia
# 2             Tierra y Libertad                Calle Liga Femenil
# 3                 Nueva Morelos                  Calle Marea Alta
# 4         Antonio I. Villarreal  Calle Veteranos de la Revolución
#
#   Número de vialidad (en su caso) Tipo de abastecimiento  \
# 0                      Sin número             Contenedor
# 1                      Sin número             Contenedor
# 2                      Sin número             Contenedor
# 3                      Sin número             Contenedor
# 4                      Sin número             Contenedor
#
#                                         Días                Horarios  \
# 0  Lunes, Martes, Miércoles, Jueves y Viernes  8:00 a.m. a 5:00 p.m.
# 1  Lunes, Martes, Miércoles, Jueves y Viernes  8:00 a.m. a 5:00 p.m.
# 2  Lunes, Martes, Miércoles, Jueves y Viernes  8:00 a.m. a 5:00 p.m.
# 3  Lunes, Martes, Miércoles, Jueves y Viernes  8:00 a.m. a 5:00 p.m.
# 4  Lunes, Martes, Miércoles, Jueves y Viernes  8:00 a.m. a 5:00 p.m.
#
#   Capacidad de la unidad
# 0             1000 litros
# 1             1000 litros
# 2             1000 litros
# 3             1000 litros
# 4             1000 litros

# %%
# Step 4: Standardize 'Tipo de abastecimiento' (Supply Type)
df['Tipo de abastecimiento'] = df['Tipo de abastecimiento'].str.strip().str.lower()

# %%
# Step 5: Check for missing values
df.dropna(inplace=True)  # Remove rows with missing values

# %%
renamed_df = df.rename(columns={"Nombre del punto de distribución": "Establecimiento", 
                                "Denominación del asentamiento":"Colonia", 
                                "Nombre de la vialidad":"Vialidad"})

renamed_df.head(5)
# Out:
#    ID         Fecha   Latitude   Longitude  \
# 0   1  2023-Octubre  25.635220 -100.299069
# 1   2  2023-Octubre  25.639017 -100.309480
# 2   3  2023-Octubre  25.741159 -100.338104
# 3   4  2023-Octubre  25.718642 -100.346749
# 4   5  2023-Octubre  25.704949 -100.355654
#
#                                      Establecimiento Tipo de asentamiento   \
# 0  Centro de Bienestar Familiar Burócratas munici...               Colonia
# 1    Centro de Bienestar Familiar  Valle del Mirador               Colonia
# 2     Centro de Bienestar Familiar Tierra y Libertad               Colonia
# 3         Centro de Bienestar Familiar Nueva Morelos               Colonia
# 4  Centro de Bienestar Familiar Antonio I. Villar...               Colonia
#
#                   Colonia                          Vialidad  \
# 0  Burócratas Municipales             Avenida Alfonso Reyes
# 1       Valle del Mirador                Calle Paseo Alicia
# 2       Tierra y Libertad                Calle Liga Femenil
# 3           Nueva Morelos                  Calle Marea Alta
# 4   Antonio I. Villarreal  Calle Veteranos de la Revolución
#
#   Número de vialidad (en su caso) Tipo de abastecimiento  \
# 0                      Sin número             contenedor
# 1                      Sin número             contenedor
# 2                      Sin número             contenedor
# 3                      Sin número             contenedor
# 4                      Sin número             contenedor
#
#                                         Días                Horarios  \
# 0  Lunes, Martes, Miércoles, Jueves y Viernes  8:00 a.m. a 5:00 p.m.
# 1  Lunes, Martes, Miércoles, Jueves y Viernes  8:00 a.m. a 5:00 p.m.
# 2  Lunes, Martes, Miércoles, Jueves y Viernes  8:00 a.m. a 5:00 p.m.
# 3  Lunes, Martes, Miércoles, Jueves y Viernes  8:00 a.m. a 5:00 p.m.
# 4  Lunes, Martes, Miércoles, Jueves y Viernes  8:00 a.m. a 5:00 p.m.
#
#   Capacidad de la unidad
# 0             1000 litros
# 1             1000 litros
# 2             1000 litros
# 3             1000 litros
# 4             1000 litros

# %%
# Step 5: Save cleaned data to a new CSV for JavaScript visualization
renamed_df.to_csv('Resources/cleaned_water_distribution.csv', index=False)
